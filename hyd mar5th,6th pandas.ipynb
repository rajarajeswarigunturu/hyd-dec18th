# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.dtypes # column names with type
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()# gives all the statistical values of the dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes=="object" # finding which is object which is not
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes=="object"] # seperating only object
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index #gives index of objects
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name=df.dtypes[df.dtypes=="object"].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name] # categorical columns
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df["rajeswari"]="pavan"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 0        0         A/5 21171   7.2500   NaN        S     pavan
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 4        0            373450   8.0500   NaN        S     pavan
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
# 889      0            111369  30.0000  C148        C     pavan
# 890      0            370376   7.7500   NaN        Q     pavan
#
# [891 rows x 13 columns]

# %%
df['Name'][0:15]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][:]# gives only names
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][0:20:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 16                                 Rice, Master. Eugene
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# Name: Name, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 0        0         A/5 21171   7.2500   NaN        S     pavan
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 4        0            373450   8.0500   NaN        S     pavan
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
# 889      0            111369  30.0000  C148        C     pavan
# 890      0            370376   7.7500   NaN        Q     pavan
#
# [891 rows x 13 columns]

# %%
df['Age'] # finding null values in Age column
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull() # if null gives true otherwise false
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull()==True].index # gives index of nullvalues of age column
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
ind=df[df['Age'].isnull()==True].index

# %%
ind
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(ind)
# Out:
# 177

# %%
len(df[df['Age'].isnull()==True].index)#
# Out:
# 177

# %%
# finding the number of null values present 
# in age column at particular indexes

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked rajeswari
# 5      male  NaN      0      0      330877   8.4583   NaN        Q     pavan
# 17     male  NaN      0      0      244373  13.0000   NaN        S     pavan
# 19   female  NaN      0      0        2649   7.2250   NaN        C     pavan
# 26     male  NaN      0      0        2631   7.2250   NaN        C     pavan
# 28   female  NaN      0      0      330959   7.8792   NaN        Q     pavan
# ..      ...  ...    ...    ...         ...      ...   ...      ...       ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C     pavan
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S     pavan
# 868    male  NaN      0      0      345777   9.5000   NaN        S     pavan
# 878    male  NaN      0      0      349217   7.8958   NaN        S     pavan
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S     pavan
#
# [177 rows x 13 columns]

# %%
# gives entire data at which age column have null values

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked rajeswari
# 5      male  NaN      0      0      330877   8.4583   NaN        Q     pavan
# 17     male  NaN      0      0      244373  13.0000   NaN        S     pavan
# 19   female  NaN      0      0        2649   7.2250   NaN        C     pavan
# 26     male  NaN      0      0        2631   7.2250   NaN        C     pavan
# 28   female  NaN      0      0      330959   7.8792   NaN        Q     pavan
# ..      ...  ...    ...    ...         ...      ...   ...      ...       ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C     pavan
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S     pavan
# 868    male  NaN      0      0      345777   9.5000   NaN        S     pavan
# 878    male  NaN      0      0      349217   7.8958   NaN        S     pavan
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S     pavan
#
# [177 rows x 13 columns]

# %%
# above method is the second method

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 0        0         A/5 21171   7.2500   NaN        S     pavan
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 4        0            373450   8.0500   NaN        S     pavan
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
# 889      0            111369  30.0000  C148        C     pavan
# 890      0            370376   7.7500   NaN        Q     pavan
#
# [891 rows x 13 columns]

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare']) # finding out max fare using max function
# Out:
# 512.3292

# %%
df[df['Fare']==max(df['Fare'])]
# details of persons who paid max fare
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     rajeswari
# 258     pavan
# 679     pavan
# 737     pavan

# %%
# names of the persons who paid max fare
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked rajeswari
# 0      0         A/5 21171   7.2500   NaN        S     pavan
# 1      0          PC 17599  71.2833   C85        C     pavan
# 2      0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3      0            113803  53.1000  C123        S     pavan
# 4      0            373450   8.0500   NaN        S     pavan

# %%
1 . Find out how many male and female passenger was onboarded .
2. how many survived we have .
3. how many casuality we have 
4 . what is name of a person who is the eldest one . 
5 . how many passenger do we have in first , second and third class 
6. how many person we have whose name starts with "s"
7. try to create a new column which is a summation  of "SibSp" and "parch"
8 . how many person do we have below age of 25 .
9 . how many person died whose age was less then 40 
10 . from a  cabin column seperate text and numeric value .
# Out:
#   File "C:\Users\91903\AppData\Local\Temp/ipykernel_55328/1854872237.py", line 1
#     1 . Find out how many male and female passenger was onboarded .
#              ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 0        0         A/5 21171   7.2500   NaN        S     pavan
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 4        0            373450   8.0500   NaN        S     pavan
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
# 889      0            111369  30.0000  C148        C     pavan
# 890      0            370376   7.7500   NaN        Q     pavan
#
# [891 rows x 13 columns]

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df[df['Sex']=="male"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked rajeswari
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S     pavan
# 4    35.0      0      0            373450   8.0500   NaN        S     pavan
# 5     NaN      0      0            330877   8.4583   NaN        Q     pavan
# 6    54.0      0      0             17463  51.8625   E46        S     pavan
# 7     2.0      3      1            349909  21.0750   NaN        S     pavan
# ..    ...    ...    ...               ...      ...   ...      ...       ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S     pavan
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S     pavan
# 886  27.0      0      0            211536  13.0000   NaN        S     pavan
# 889  26.0      0      0            111369  30.0000  C148        C     pavan
# 890  32.0      0      0            370376   7.7500   NaN        Q     pavan
#
# [577 rows x 13 columns]

# %%
df[df['Sex']=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 8        2            347742  11.1333   NaN        S     pavan
# 9        0            237736  30.0708   NaN        C     pavan
# ..     ...               ...      ...   ...      ...       ...
# 880      1            230433  26.0000   NaN        S     pavan
# 882      0              7552  10.5167   NaN        S     pavan
# 885      5            382652  29.1250   NaN        Q     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
#
# [314 rows x 13 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari
# 0        0         A/5 21171   7.2500   NaN        S     pavan
# 1        0          PC 17599  71.2833   C85        C     pavan
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan
# 3        0            113803  53.1000  C123        S     pavan
# 4        0            373450   8.0500   NaN        S     pavan
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     pavan
# 887      0            112053  30.0000   B42        S     pavan
# 888      2        W./C. 6607  23.4500   NaN        S     pavan
# 889      0            111369  30.0000  C148        C     pavan
# 890      0            370376   7.7500   NaN        Q     pavan
#
# [891 rows x 13 columns]

# %%
df[df['Survived']==0].index
# Out:
# Int64Index([  0,   4,   5,   6,   7,  12,  13,  14,  16,  18,
#             ...
#             877, 878, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=549)

# %%
df[df['Survived']==1].index
# Out:
# Int64Index([  1,   2,   3,   8,   9,  10,  11,  15,  17,  19,
#             ...
#             865, 866, 869, 871, 874, 875, 879, 880, 887, 889],
#            dtype='int64', length=342)

# %%
df[df['Age']==max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df['Pclass']==3].index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,  10,  12,  13,  14,
#             ...
#             875, 876, 877, 878, 881, 882, 884, 885, 888, 890],
#            dtype='int64', length=491)

# %%
df[df['Pclass']==2].index
# Out:
# Int64Index([  9,  15,  17,  20,  21,  33,  41,  43,  53,  56,
#             ...
#             848, 854, 861, 864, 865, 866, 874, 880, 883, 886],
#            dtype='int64', length=184)

# %%
df[df['Pclass']==1].index
# Out:
# Int64Index([  1,   3,   6,  11,  23,  27,  30,  31,  34,  35,
#             ...
#             853, 856, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=216)

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["newcolumn"]=df["SibSp"] +df["Parch"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked rajeswari  newcolumn
# 0        0         A/5 21171   7.2500   NaN        S     pavan          1
# 1        0          PC 17599  71.2833   C85        C     pavan          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S     pavan          0
# 3        0            113803  53.1000  C123        S     pavan          1
# 4        0            373450   8.0500   NaN        S     pavan          0
# ..     ...               ...      ...   ...      ...       ...        ...
# 886      0            211536  13.0000   NaN        S     pavan          0
# 887      0            112053  30.0000   B42        S     pavan          0
# 888      2        W./C. 6607  23.4500   NaN        S     pavan          3
# 889      0            111369  30.0000  C148        C     pavan          0
# 890      0            370376   7.7500   NaN        Q     pavan          0
#
# [891 rows x 14 columns]

# %%
df[df['Age']<25].index
# Out:
# Int64Index([  0,   7,   9,  10,  12,  14,  16,  22,  24,  27,
#             ...
#             855, 858, 861, 864, 869, 875, 876, 877, 882, 887],
#            dtype='int64', length=278)

# %%
for i in df['Survived']=0 and df['Age'] < 40:
    print(i)
# Out:
#   File "C:\Users\91903\AppData\Local\Temp/ipykernel_55328/3325939394.py", line 1
#     for i in df['Survived']=0 and df['Age'] < 40:
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 1 . Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# 1.Find out how many male and female passenger was onboarded .

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Find out how many male and female passenger was onboarded .

# %%
df["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex']=="male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
len(df[df['Sex']=="male"]) # 2nd way
# Out:
# 577

# %%
len(df[df['Sex']=="female"])
# Out:
# 314

# %%
# 3rd way
df.groupby("Sex")['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
# 2. how many survived we have .

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name=df.dtypes[df.dtypes=="object"].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['cabin_Number'] = df['Cabin'].str.replace('([A-Za-z]+)', '')
df['cabin_Letter'] = df['Cabin'].str.extract('([A-Za-z]+)')
# Out:
# C:\Users\91903\AppData\Local\Temp/ipykernel_55324/1424287435.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cabin_Number'] = df['Cabin'].str.replace('([A-Za-z]+)', '')

# %%
df2 = pd.DataFrame(df.Cabin.str.split('([a-zA-Z]+)([^a-zA-Z]+)'))
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
#above answer is for last question

# %%
import re

replace = re.compile("([a-zA-Z]+)")

df['string_cabin_list'] = df['Cabin'].str.extract(replace)
df['num_cabin_list'] = df['Cabin'].str.replace(replace, "")

# %%
df['string_cabin_list']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin_list, Length: 891, dtype: object

# %%
df['num_cabin_list']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: num_cabin_list, Length: 891, dtype: object

# %%
len(df[(df['Survived']== 0) & (df['Age'] < 40)])
# Out:
# 322

# %%
len(df[df['Age']<25])
# Out:
# 278

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str

# %%
df[df['Name'].str.startswith("s")]['Name']
# Out:
# Series([], Name: Name, dtype: object)

# %%
len(df[df['Name'].str.startswith("S")]['Name'])
# Out:
# 86

# %%
df.groupby('Pclass')

# %%
df.groupby('Pclass')['Pclass']

# %%
df.groupby('Pclass')['Pclass'].count() # one way
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age']==df['Age'].max
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age']==df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age']==df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
len(df[df['Survived']==0])
# Out:
# 549

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 08-12-2023  09:20    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 08-12-2023  00:09    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# 11-09-2023  21:28            23,182 2023 21dec ipynb.ipynb
# 14-09-2023  20:19            30,516 2023 23dec, 8th jan function ipynb.ipynb
# 01-06-2023  15:09             9,891 2023 6th feb sql day2.ipynb
# 11-09-2023  13:41            46,294 2023 dec18th set tuple dict ipynb part2.ipynb
# 11-09-2023  12:26            25,571 2023 dec19th new ipynb if else.ipynb
# 10-09-2023  22:01            68,837 2023 dec5th str,list new ipynb.ipynb
# 07-05-2023  19:28           110,238 2023 modules and pycharm.ipynb
# 11-05-2023  16:37            11,034 2023 sql part 1 feb5th.ipynb
# 18-08-2023  11:24            21,293 20thdec practice.ipynb
# 09-04-2022  15:17            23,165 21st dec practice.ipynb
# 14-10-2022  16:05           100,700 22jan module discussion.ipynb
# 14-10-2022  17:38             5,648 22jan oops concept.ipynb
# 30-07-2022  13:00                 0 22jan.py
# 30-07-2022  13:15                29 22jan1.py
# 26-06-2022  21:49            22,964 23decrestart.ipynb
# 11-04-2022  17:05            33,103 23rd dec practice.ipynb
# 19-10-2022  14:31             8,048 23rd jan oops concept.ipynb
# 24-08-2022  17:17            34,953 29jan oops.ipynb
# 25-06-2022  23:46            18,529 8th jan .ipynb
# 16-10-2022  22:12            38,125 8th jan practice.ipynb
# 06-10-2022  19:59           105,942 9th jan iterator,generator and filesystem.ipynb
# 27-06-2022  21:47            69,372 9thjanpractice.ipynb
# 07-05-2023  18:05                 0 akhil.py
# 21-02-2022  16:16    <DIR>          anaconda3
# 02-12-2022  12:49             1,089 API FLASK1.ipynb
# 04-07-2023  11:44            14,141 Assignment 8.ipynb
# 04-07-2023  12:15             4,535 Assignment 9.ipynb
# 28-02-2022  14:55             8,732 Assignment1.ipynb
# 08-05-2022  18:10            15,719 assignment2.ipynb
# 22-08-2022  11:36            15,644 Assignment4.ipynb
# 14-10-2022  11:56    <DIR>          autoCompletion
# 16-11-2022  14:49           461,474 bank.csv
# 16-11-2022  14:46           461,474 bank.xls
# 23-09-2022  02:00             1,007 change.log
# 02-04-2023  19:10    <DIR>          Contacts
# 17-01-2022  06:13             4,843 contextMenu.xml
# 15-11-2022  11:25             5,845 cricket.csv
# 10-11-2022  11:31             1,560 datastax.ipynb
# 07-12-2023  21:49               355 day.csv
# 03-05-2022  12:58            55,145 dec 5th practice.ipynb
# 25-08-2022  11:55            41,712 dec 5th practice2.ipynb
# 16-08-2023  13:02            23,803 dec4th practice.ipynb
# 07-12-2023  22:30               577 Details.csv
# 01-04-2022  17:58    <DIR>          Documents
# 08-12-2023  09:21    <DIR>          Downloads
# 24-04-2023  13:09                22 enapple.ini
# 13-10-2022  14:04            94,633 exception part2 and logging.ipynb
# 30-06-2022  21:18            35,344 excpthndlng2.ipynb
# 28-06-2022  23:07            12,467 exhndlng1.ipynb
# 02-04-2023  19:10    <DIR>          Favorites
# 05-10-2022  18:07            89,207 function dec 23rd class practice.ipynb
# 14-10-2022  11:56    <DIR>          functionList
# 14-10-2022  12:37               131 funmod1.py
# 14-10-2022  12:22                 0 funmod2.py
# 14-10-2022  12:53                94 funmod3.py
# 14-10-2022  13:00                40 funmod4.py
# 29-11-2022  22:57         3,078,946 graph 1.ipynb
# 30-11-2022  17:59         1,789,919 graph2.ipynb
# 01-12-2023  15:52            56,367 htd 8th jan.ipynb
# 28-11-2023  15:16                72 hyd 1.ipynb
# 02-12-2023  18:51            21,791 hyd 15th jan.ipynb
# 03-12-2023  14:53            51,859 hyd 16th jan.ipynb
# 30-11-2023  11:30            33,145 hyd 20th dec.ipynb
# 30-11-2023  20:07            18,848 hyd 21st dec.ipynb
# 01-12-2023  15:50            28,293 hyd 23rd dec.ipynb
# 02-12-2023  14:24           140,622 hyd 9th jan.ipynb
# 29-11-2023  11:37            80,734 hyd dec18th.ipynb
# 08-12-2023  00:08           804,740 hyd feb 26th,27th  pandas.ipynb
# 03-12-2023  18:14            29,972 hyd jan22nd.ipynb
# 08-12-2023  09:20           255,326 hyd mar5th,6th pandas.ipynb
# 02-12-2023  15:15           122,373 hyd practice book.ipynb
# 29-11-2023  14:02            44,090 hyd19th dec.ipynb
# 03-12-2023  18:13                 0 hydmodule1.py
# 02-12-2023  13:48               725 hydpara.txt
# 03-12-2023  14:47             1,074 hydtest.log
# 02-12-2023  18:18                19 hydtest.txt
# 02-12-2023  11:59                38 hydtest1.txt
# 03-12-2023  14:17               567 hydtest2.log
# 03-12-2023  14:42                 0 hydtest3.log
# 31-07-2022  12:59            41,601 jan22practice.ipynb
# 08-11-2022  15:10            12,288 joindb.db
# 08-11-2022  15:20             8,720 joindb.db-journal
# 08-12-2023  00:03            34,778 json_res.csv
# 28-05-2022  07:17           350,341 langs.model.xml
# 15-08-2021  05:50            35,500 LICENSE
# 06-10-2022  19:56               147 life.txt
# 02-04-2023  19:10    <DIR>          Links
# 14-10-2022  11:56    <DIR>          localization
# 06-10-2022  19:27             1,934 mahesh.txt
# 06-10-2022  18:50                51 manasa.txt
# 13-10-2022  13:52                 0 meethu.log
# 07-05-2023  18:20               180 mini.py
# 07-05-2023  17:55                 0 mod1.py
# 07-05-2023  18:12               130 mod2.py
# 07-05-2023  17:54                 0 module.py
# 14-10-2022  11:39                 0 module2.py
# 27-10-2022  12:23             5,444 mongodb.ipynb
# 02-04-2023  19:10    <DIR>          Music
# 30-07-2022  14:06               213 my_module.py
# 25-10-2022  14:40            10,208 mysql class1.ipynb
# 07-12-2023  23:32            78,962 NBA.csv
# 03-12-2023  17:57    <DIR>          notepadplus
# 05-12-2021  09:58                 0 nppLogNulContentCorruptionIssue.xml
# 25-09-2022  23:30           232,984 NppShell_06.dll
# 23-11-2022  17:51            50,763 numpy.ipynb
# 02-04-2023  19:08    <DIR>          OneDrive
# 31-07-2022  19:10             5,529 oops basic 22jan.ipynb
# 01-08-2022  15:53            11,638 oops jan23.ipynb
# 22-11-2022  21:35           107,440 pandas and numpy.ipynb
# 10-11-2022  23:34           128,025 pandas1.ipynb
# 15-11-2022  14:41           619,109 pandas2.ipynb
# 16-11-2022  15:55           141,613 pandas3.ipynb
# 17-11-2022  13:14               588 pandas4.ipynb
# 21-11-2022  19:35           173,487 pandasday4.ipynb
# 08-11-2022  14:51             8,192 person.db
# 14-10-2022  11:56    <DIR>          plugins
# 02-12-2022  11:38    <DIR>          Postman
# 03-12-2023  10:34                16 priya.txt
# 07-05-2023  19:11    <DIR>          PycharmProjects
# 29-09-2022  08:46            10,630 python assignment 5.ipynb
# 08-10-2022  23:27            14,458 python basic assignment 6.ipynb
# 15-07-2023  12:52             7,374 python basic programming assignment 11.ipynb
# 20-07-2023  15:51             6,955 python basic programming assignment 12.ipynb
# 30-09-2022  18:26             6,317 python basic programming assignment 5.ipynb
# 07-10-2022  00:13             6,545 python basic programming assignment 6.ipynb
# 13-10-2022  16:11             4,776 python basic programming assignment 7.ipynb
# 23-09-2022  16:44             7,776 python basic programming assignment4.ipynb
# 11-07-2023  15:08             1,383 python programming assignment 10.ipynb
# 14-07-2023  10:20             9,645 python programming assignment 11.ipynb
# 04-07-2023  13:58             5,375 python programming assignment 8.ipynb
# 09-07-2023  17:13            10,556 python programming assignment 9.ipynb
# 22-08-2022  15:53             4,908 python programming assignment1.ipynb
# 21-09-2022  14:12             4,130 python programming assignment2.ipynb
# 22-09-2022  14:06            26,533 python programming assignment3.ipynb
# 08-11-2022  14:54             8,192 raj.db
# 08-10-2022  22:02                 9 raji.txt
# 06-10-2022  19:42                58 rama.txt
# 27-05-2021  04:27             1,526 readme.txt
# 21-06-2022  13:45            23,522 restart 20dec.ipynb
# 21-06-2022  17:07            21,171 restart 21dec.ipynb
# 17-06-2022  16:30            17,684 restart dec19.ipynb
# 14-10-2022  12:24                44 rfunmod1.py
# 13-10-2022  13:29               480 ritu.log
# 10-11-2022  19:13            14,905 Sales.csv
# 10-11-2022  19:36               201 sample.csv
# 10-11-2022  23:15               232 sample.xls.csv
# 07-12-2023  23:10           167,424 sample-xls-file-for-testing.xls
# 02-04-2023  19:10    <DIR>          Saved Games
# 30-11-2022  14:30    <DIR>          seaborn-data
# 02-04-2023  19:10    <DIR>          Searches
# 13-10-2022  13:35               904 seethu.log
# 27-05-2021  04:27               965 shortcuts.xml
# 08-11-2022  19:47            77,976 sql lite 08112022.ipynb
# 25-10-2022  14:40             8,079 sql part2.ipynb
# 22-10-2022  23:32             7,994 sql2.ipynb
# 20-09-2022  22:39           174,773 stylers.model.xml
# 30-09-2022  17:37             6,652 sudhasirqsadans.ipynb
# 30-06-2022  22:41               310 test.log
# 02-12-2023  11:55                 0 test.txt
# 13-10-2022  12:17                 4 test1
# 13-10-2022  11:53                22 test1.txt
# 30-07-2022  13:47               225 test11.py
# 30-06-2022  22:53               278 test2.log
# 27-06-2022  13:24                31 test2.txt
# 14-10-2022  11:29                 0 test3.py
# 28-06-2022  23:08                11 test3.txt
# 30-06-2022  16:50                 0 test43.txt
# 27-06-2022  21:30               551 test5.txt
# 07-05-2023  18:31               138 testu.py
# 14-10-2022  11:56    <DIR>          themes
# 28-02-2022  20:21            53,575 Untitled.ipynb
# 01-03-2022  14:37                72 Untitled1.ipynb
# 27-02-2023  14:30             1,679 Untitled10.ipynb
# 09-05-2023  10:29                72 Untitled11.ipynb
# 04-07-2023  13:54             8,651 Untitled12.ipynb
# 03-08-2023  10:33             3,443 Untitled13.ipynb
# 07-12-2023  21:37                72 Untitled14.ipynb
# 03-03-2022  15:56            36,553 Untitled2.ipynb
# 21-06-2022  15:32               588 Untitled3.ipynb
# 27-06-2022  22:55             5,082 Untitled4.ipynb
# 29-06-2022  00:49             5,617 Untitled5.ipynb
# 30-07-2022  12:48             1,518 Untitled6.ipynb
# 24-08-2022  17:18            18,874 Untitled7.ipynb
# 16-10-2022  10:53               588 Untitled8.ipynb
# 28-11-2022  14:32               796 Untitled9.ipynb
# 14-10-2022  11:56    <DIR>          updater
# 02-04-2023  19:10    <DIR>          Videos
#              171 File(s)     16,395,702 bytes
#               32 Dir(s)  414,765,256,704 bytes free

# %%
pd.read_csv("bank.csv", sep=';')
# file is seperated with semicolon, so
# seperator used is sep;
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df=pd.read_csv("bank.csv", sep=';')

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %% [markdown]
# # 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .
#
#
# https://codeshare.io/X8PY8Y

# %%
#1 . how many campaign available in this dataset

# %%
df["campaign"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        4
# 4        1
#         ..
# 4516     5
# 4517     1
# 4518    11
# 4519     4
# 4520     2
# Name: campaign, Length: 4521, dtype: int64

# %%
df["campaign"].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(df["campaign"].unique())
# Out:
# 32

# %%
len(set(list(df['campaign'])))
# Out:
# 32

# %%
# 2 . how many users do we have with housing and personal loan

# %%
df[(df['housing']!='yes') & (df['loan']!='yes')]
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 5      35   management    single   tertiary      no      747      no   no
# 12     36   technician   married   tertiary      no     1109      no   no
# 13     20      student    single  secondary      no      502      no   no
# 16     56   technician   married  secondary      no     4073      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4506   42   unemployed  divorced   tertiary      no     -166      no   no
# 4509   51   technician   married   tertiary      no     2506      no   no
# 4513   49  blue-collar   married  secondary      no      322      no   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   19   oct        79         1     -1         0  unknown   no
# 5     cellular   23   feb       141         2    176         3  failure   no
# 12    cellular   13   aug       328         2     -1         0  unknown   no
# 13    cellular   30   apr       261         1     -1         0  unknown  yes
# 16    cellular   27   aug       239         5     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4506  cellular   29   aug        85         4     -1         0  unknown   no
# 4509  cellular   30   nov       210         3     -1         0  unknown   no
# 4513  cellular   14   aug       356         2     -1         0  unknown   no
# 4518  cellular   19   aug       151        11     -1         0  unknown   no
# 4519  cellular    6   feb       129         4    211         3    other   no
#
# [1677 rows x 17 columns]

# %%
df1=df[(df['housing']!='yes') & (df['loan']!='yes')]

# %%
df1
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 5      35   management    single   tertiary      no      747      no   no
# 12     36   technician   married   tertiary      no     1109      no   no
# 13     20      student    single  secondary      no      502      no   no
# 16     56   technician   married  secondary      no     4073      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4506   42   unemployed  divorced   tertiary      no     -166      no   no
# 4509   51   technician   married   tertiary      no     2506      no   no
# 4513   49  blue-collar   married  secondary      no      322      no   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   19   oct        79         1     -1         0  unknown   no
# 5     cellular   23   feb       141         2    176         3  failure   no
# 12    cellular   13   aug       328         2     -1         0  unknown   no
# 13    cellular   30   apr       261         1     -1         0  unknown  yes
# 16    cellular   27   aug       239         5     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4506  cellular   29   aug        85         4     -1         0  unknown   no
# 4509  cellular   30   nov       210         3     -1         0  unknown   no
# 4513  cellular   14   aug       356         2     -1         0  unknown   no
# 4518  cellular   19   aug       151        11     -1         0  unknown   no
# 4519  cellular    6   feb       129         4    211         3    other   no
#
# [1677 rows x 17 columns]

# %%
# how many person do we have whose age is 60+ .

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
len(df[df['age']>60])
# Out:
# 127

# %%
# 4 . in which month we have trageted most of the customer .

# %%
df['month']
# Out:
# 0       oct
# 1       may
# 2       apr
# 3       jun
# 4       may
#        ...
# 4516    jul
# 4517    may
# 4518    aug
# 4519    feb
# 4520    apr
# Name: month, Length: 4521, dtype: object

# %%
df['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
df['month'].value_counts().index[0]
# Out:
# 'may'

# %%
# 5 . which mode of call is giving you more result
# Out:
#   File "C:\Users\91903\AppData\Local\Temp/ipykernel_55324/1252317285.py", line 1
#     5 . which mode of call is giving you more result
#               ^
# SyntaxError: invalid syntax

# %%
df.groupby(['contact','y'])

# %%
df.groupby(['contact','y']).count()
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
#           yes    61    61     61        61        61     61        61
#
#                poutcome
# contact   y
# cellular  no       2480
#           yes       416
# telephone no        257
#           yes        44
# unknown   no       1263
#           yes        61

# %%
df_groupby=df.groupby(['contact','y']).count()

# %%
df_groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
#           yes    61    61     61        61        61     61        61
#
#                poutcome
# contact   y
# cellular  no       2480
#           yes       416
# telephone no        257
#           yes        44
# unknown   no       1263
#           yes        61

# %%
df_groupby.loc['telephone','yes'][0]
# Out:
# 44

# %%
df_groupby.loc['unknown','yes'][0]
# Out:
# 61

# %%
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
max(df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0],df_groupby.loc['cellular','yes'][0])
# Out:
# 416

# %%
# 6 . how many enterpeures do we have in this list

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df['job']=='entrepreneur'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520     True
# Name: job, Length: 4521, dtype: bool

# %%
df[df['job']=='entrepreneur']
# Out:
#       age           job   marital  education default  balance housing loan  \
# 8      41  entrepreneur   married   tertiary      no      221     yes   no
# 23     44  entrepreneur   married  secondary      no       93      no   no
# 48     32  entrepreneur    single    primary     yes     -849     yes  yes
# 71     42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 150    41  entrepreneur   married    unknown      no       89     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 4401   38  entrepreneur  divorced   tertiary      no     7929      no   no
# 4402   41  entrepreneur   married    primary      no       39     yes   no
# 4487   49  entrepreneur  divorced  secondary      no       32      no   no
# 4497   31  entrepreneur    single   tertiary      no       38      no   no
# 4520   44  entrepreneur    single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 8      unknown   14   may        57         2     -1         0  unknown   no
# 23    cellular    7   jul       125         2     -1         0  unknown   no
# 48    cellular    4   feb       204         1     -1         0  unknown   no
# 71     unknown    5   may       380         1     -1         0  unknown   no
# 150    unknown    6   may       333         2     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4401  cellular    8   jul       182         3     -1         0  unknown   no
# 4402  cellular   21   nov       549         2     -1         0  unknown  yes
# 4487  cellular    5   feb       128         1     -1         0  unknown   no
# 4497  cellular   20   nov       185         2     -1         0  unknown   no
# 4520  cellular    3   apr       345         2    249         7    other   no
#
# [168 rows x 17 columns]

# %%
#7 . how many customers do we have with negative balance

# %%
df[df['balance']<0]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 48     cellular    4   feb       204         1     -1         0  unknown   no
# 60    telephone    8   jul       554         3     -1         0  unknown   no
# 92     cellular   18   may       391         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4474  telephone   10   jul        73         1     -1         0  unknown   no
# 4502   cellular    5   feb        43         1     -1         0  unknown   no
# 4506   cellular   29   aug        85         4     -1         0  unknown   no
# 4516   cellular   30   jul       329         5     -1         0  unknown   no
# 4517    unknown    9   may       153         1     -1         0  unknown   no
#
# [366 rows x 17 columns]

# %%
df[df['balance']<0]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 48     cellular    4   feb       204         1     -1         0  unknown   no
# 60    telephone    8   jul       554         3     -1         0  unknown   no
# 92     cellular   18   may       391         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4474  telephone   10   jul        73         1     -1         0  unknown   no
# 4502   cellular    5   feb        43         1     -1         0  unknown   no
# 4506   cellular   29   aug        85         4     -1         0  unknown   no
# 4516   cellular   30   jul       329         5     -1         0  unknown   no
# 4517    unknown    9   may       153         1     -1         0  unknown   no
#
# [366 rows x 17 columns]

# %%
# 8. prepare a group of data based on education level .

# %%
df.groupby('education')

# %%
df.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
l=[]
for i in df['education'].unique():
    l.append(df[df['education']==i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4480   cellular   16   apr       743         1     -1         0  unknown   no
# 4485   cellular   11   may       238         2    361         5  failure   no
# 4486    unknown    9   may       514         1     -1         0  unknown   no
# 4499   cellular   21   nov       362         1     -1         0  unknown   no
# 4503   cellular   29   jul       816         6     -1         0  unknown  yes
#
# [678 rows x 17 columns]

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1     cellular   11   may       220         1    339         4  failure  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 10     unknown   20   may       273         1     -1         0  unknown  no
# 11    cellular   17   apr       113         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4514  cellular   20   apr        45         4    153         1  failure  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
#
# [2306 rows x 17 columns]

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 5     cellular   23   feb       141         2    176         3  failure  no
# 6     cellular   14   may       341         1    330         2    other  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4501  cellular   26   aug        63         4     -1         0  unknown  no
# 4506  cellular   29   aug        85         4     -1         0  unknown  no
# 4509  cellular   30   nov       210         3     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [1350 rows x 17 columns]

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 20     cellular   18   nov        96         2     -1         0  unknown   no
# 27    telephone   17   aug       119         1    105         2  failure   no
# 49     cellular   27   jan       181         1     92         1  success  yes
# 132     unknown   30   may        67         3     -1         0  unknown   no
# 133    cellular    8   may        85         1    168         2  failure   no
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4337  telephone   16   oct       434         1     57         1  failure  yes
# 4342  telephone   31   jul      1088        17     -1         0  unknown  yes
# 4428   cellular    2   feb       212         1    249         2    other   no
# 4471   cellular   21   nov       216         4     -1         0  unknown   no
# 4508    unknown   16   may       509         2     -1         0  unknown   no
#
# [187 rows x 17 columns]
