# %% [markdown]
# #pandas

# %%
 import pandas as pd

# %%
# file read and write operations

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePathOrBuffer', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=False, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=Fals
# ...

# %%
# pandas takes first row as to column names

# %%
# row indexes bydefault it takes

# %%
# pandas is used or read or perform some operation on 
# structured data

# %%
# data type of entire data in pandas is called dataframe

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  21:38    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
pd.read_csv("Details.csv")
# Out:
#    S.no    Name  Age  Designation         Place  Salary
# 0     1   Pavan   35      Husband       Chirala   30000
# 1     2    Raji   35         Wife  Narasaraopet   20000
# 2     3   Sanvi    6     Daughter       Chirala   50000
# 3     4   Seivi    6     Daughter       Chirala   50000
# 4     5    Rama   55       Mother  Narasaraopet   12000
# 5     6  Ramana   85      Gmother  Narasaraopet   15000
# 6     7  Manasa   30       Sister  Narasaraopet   30000
# 7     8   Ramya   30    Lawsister     Hyderabad   20000
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000
# 9    10   Tinku   28    Lawsister     Hyderabad   30000

# %%
pd.read_csv('C:\Users\91903\day.csv')
# Out:
#   File "C:\Users\91903\AppData\Local\Temp/ipykernel_45832/3105383855.py", line 1
#     pd.read_csv('C:\Users\91903\day.csv')
#                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# if u get unicode error , place r infront of c:\

# %%
pd.read_csv(r'C:\Users\91903\day.csv')
# Out:
#     Numeric  Numeric-2 Numeric-Suffix
# 0         1          1            1st
# 1         2          2            2nd
# 2         3          3            3rd
# 3         4          4            4th
# 4         5          5            5th
# 5         6          6            6th
# 6         7          7            7th
# 7         8          8            8th
# 8         9          9            9th
# 9        10         10           10th
# 10       11         11           11th
# 11       12         12           12th
# 12       13         13           13th
# 13       14         14           14th
# 14       15         15           15th
# 15       16         16           16th
# 16       17         17           17th
# 17       18         18           18th
# 18       19         19           19th
# 19       20         20           20th
# 20       21         21           21st
# 21       22         22           22nd
# 22       23         23           23rd
# 23       24         24           24th
# ...

# %%
df=pd.read_csv(r'C:\Users\91903\day.csv')

# %%
df
# Out:
#     Numeric  Numeric-2 Numeric-Suffix
# 0         1          1            1st
# 1         2          2            2nd
# 2         3          3            3rd
# 3         4          4            4th
# 4         5          5            5th
# 5         6          6            6th
# 6         7          7            7th
# 7         8          8            8th
# 8         9          9            9th
# 9        10         10           10th
# 10       11         11           11th
# 11       12         12           12th
# 12       13         13           13th
# 13       14         14           14th
# 14       15         15           15th
# 15       16         16           16th
# 16       17         17           17th
# 17       18         18           18th
# 18       19         19           19th
# 19       20         20           20th
# 20       21         21           21st
# 21       22         22           22nd
# 22       23         23           23rd
# 23       24         24           24th
# ...

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  21:56    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
df=pd.read_csv("Details.csv")

# %%
df
# Out:
#    S.no    Name  Age  Designation         Place  Salary
# 0     1   Pavan   35      Husband       Chirala   30000
# 1     2    Raji   35         Wife  Narasaraopet   20000
# 2     3   Sanvi    6     Daughter       Chirala   50000
# 3     4   Seivi    6     Daughter       Chirala   50000
# 4     5    Rama   55       Mother  Narasaraopet   12000
# 5     6  Ramana   85      Gmother  Narasaraopet   15000
# 6     7  Manasa   30       Sister  Narasaraopet   30000
# 7     8   Ramya   30    Lawsister     Hyderabad   20000
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000
# 9    10   Tinku   28    Lawsister     Hyderabad   30000

# %%
pd.read_csv("Details.csv",header=None)
# this removes header means column names
# Out:
#        0       1    2            3             4       5
# 0   S.no    Name  Age  Designation         Place  Salary
# 1      1   Pavan   35      Husband       Chirala   30000
# 2      2    Raji   35         Wife  Narasaraopet   20000
# 3      3   Sanvi    6     Daughter       Chirala   50000
# 4      4   Seivi    6     Daughter       Chirala   50000
# 5      5    Rama   55       Mother  Narasaraopet   12000
# 6      6  Ramana   85      Gmother  Narasaraopet   15000
# 7      7  Manasa   30       Sister  Narasaraopet   30000
# 8      8   Ramya   30    Lawsister     Hyderabad   20000
# 9      9  Himani    6  Lawdaughter     Hyderabad   50000
# 10    10   Tinku   28    Lawsister     Hyderabad   30000

# %%
pd.read_csv("Details.csv", names=[100,200,300,400,500,600])
# this changes column names
# Out:
#      100     200  300          400           500     600
# 0   S.no    Name  Age  Designation         Place  Salary
# 1      1   Pavan   35      Husband       Chirala   30000
# 2      2    Raji   35         Wife  Narasaraopet   20000
# 3      3   Sanvi    6     Daughter       Chirala   50000
# 4      4   Seivi    6     Daughter       Chirala   50000
# 5      5    Rama   55       Mother  Narasaraopet   12000
# 6      6  Ramana   85      Gmother  Narasaraopet   15000
# 7      7  Manasa   30       Sister  Narasaraopet   30000
# 8      8   Ramya   30    Lawsister     Hyderabad   20000
# 9      9  Himani    6  Lawdaughter     Hyderabad   50000
# 10    10   Tinku   28    Lawsister     Hyderabad   30000

# %%
pd.read_csv("Details.csv")
# Out:
#    S.no    Name  Age  Designation         Place  Salary
# 0     1   Pavan   35      Husband       Chirala   30000
# 1     2    Raji   35         Wife  Narasaraopet   20000
# 2     3   Sanvi    6     Daughter       Chirala   50000
# 3     4   Seivi    6     Daughter       Chirala   50000
# 4     5    Rama   55       Mother  Narasaraopet   12000
# 5     6  Ramana   85      Gmother  Narasaraopet   15000
# 6     7  Manasa   30       Sister  Narasaraopet   30000
# 7     8   Ramya   30    Lawsister     Hyderabad   20000
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000
# 9    10   Tinku   28    Lawsister     Hyderabad   30000

# %%
pd.read_csv("Details.csv")
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     1   Pavan   35      Husband       Chirala   30000   pavan@gmail.com
# 1     2    Raji   35         Wife  Narasaraopet   20000    raji@gmail.com
# 2     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 3     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 4     5    Rama   55       Mother  Narasaraopet   12000    rama@gmail.com
# 5     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 6     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 7     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 9    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
pd.read_csv("Details.csv",sep='@')
# Out:
#                                               S.no,Name,Age,Designation,Place,Salary,Email
# 1,Pavan,35,Husband,Chirala,30000,pavan                                           gmail.com
# 2,Raji,35,Wife,Narasaraopet,20000,raji                                           gmail.com
# 3,Sanvi,6,Daughter,Chirala,50000,sanvi                                           gmail.com
# 4,Seivi,6,Daughter,Chirala,50000,seivi                                           gmail.com
# 5,Rama,55,Mother,Narasaraopet,12000,rama                                         gmail.com
# 6,Ramana,85,Gmother,Narasaraopet,15000,ramana                                    gmail.com
# 7,Manasa,30,Sister,Narasaraopet,30000,manasa                                     gmail.com
# 8,Ramya,30,Lawsister,Hyderabad,20000,ramya                                       gmail.com
# 9,Himani,6,Lawdaughter,Hyderabad,50000,himani                                    gmail.com
# ...

# %%
df=pd.read_csv("Details.csv",sep=',')

# %%
df
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     1   Pavan   35      Husband       Chirala   30000   pavan@gmail.com
# 1     2    Raji   35         Wife  Narasaraopet   20000    raji@gmail.com
# 2     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 3     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 4     5    Rama   55       Mother  Narasaraopet   12000    rama@gmail.com
# 5     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 6     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 7     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 9    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     1   Pavan   35      Husband       Chirala   30000   pavan@gmail.com
# 1     2    Raji   35         Wife  Narasaraopet   20000    raji@gmail.com
# 2     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 3     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 4     5    Rama   55       Mother  Narasaraopet   12000    rama@gmail.com
# 5     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 6     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 7     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 8     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 9    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
pd.read_csv("Details.csv",skiprows=[1,2,5])
#skips the rows
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 1     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 2     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 3     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 4     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 5     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 6    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
df=pd.read_csv("Details.csv",skiprows=[1,2,5])

# %%
df
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 1     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 2     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 3     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 4     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 5     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 6    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  22:36    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
df.dtypes # columns datatypes
# Out:
# S.no            int64
# Name           object
# Age             int64
# Designation    object
# Place          object
# Salary          int64
# Email          object
# dtype: object

# %%
df.head() # head gives top 5 rows
# Out:
#    S.no    Name  Age Designation         Place  Salary             Email
# 0     3   Sanvi    6    Daughter       Chirala   50000   sanvi@gmail.com
# 1     4   Seivi    6    Daughter       Chirala   50000   seivi@gmail.com
# 2     6  Ramana   85     Gmother  Narasaraopet   15000  ramana@gmail.com
# 3     7  Manasa   30      Sister  Narasaraopet   30000  manasa@gmail.com
# 4     8   Ramya   30   Lawsister     Hyderabad   20000   ramya@gmail.com

# %%
df.tail()# this gives last 5 rows from the bottom
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 2     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 3     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 4     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 5     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 6    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
df.columns # gives column names
# Out:
# Index(['S.no', 'Name', 'Age', 'Designation', 'Place', 'Salary', 'Email'], dtype='object')

# %%
df.dtypes # gives types of column values # object= category
# Out:
# S.no            int64
# Name           object
# Age             int64
# Designation    object
# Place          object
# Salary          int64
# Email          object
# dtype: object

# %%
df
# Out:
#    S.no    Name  Age  Designation         Place  Salary             Email
# 0     3   Sanvi    6     Daughter       Chirala   50000   sanvi@gmail.com
# 1     4   Seivi    6     Daughter       Chirala   50000   seivi@gmail.com
# 2     6  Ramana   85      Gmother  Narasaraopet   15000  ramana@gmail.com
# 3     7  Manasa   30       Sister  Narasaraopet   30000  manasa@gmail.com
# 4     8   Ramya   30    Lawsister     Hyderabad   20000   ramya@gmail.com
# 5     9  Himani    6  Lawdaughter     Hyderabad   50000  himani@gmail.com
# 6    10   Tinku   28    Lawsister     Hyderabad   30000   tinku@gmail.com

# %%
df['Name'] # gives particular column
# Out:
# 0     Sanvi
# 1     Seivi
# 2    Ramana
# 3    Manasa
# 4     Ramya
# 5    Himani
# 6     Tinku
# Name: Name, dtype: object

# %%
a=df['Name']

# %%
type(a) # series means entire row or entire column
# Out:
# pandas.core.series.Series

# %%
df[['Name','Age','Place']]# must be given in a list for multiple columns
# Out:
#      Name  Age         Place
# 0   Sanvi    6       Chirala
# 1   Seivi    6       Chirala
# 2  Ramana   85  Narasaraopet
# 3  Manasa   30  Narasaraopet
# 4   Ramya   30     Hyderabad
# 5  Himani    6     Hyderabad
# 6   Tinku   28     Hyderabad

# %%
df1=df[['Name','Age','Place']]

# %%
df1 # single column series,multi columns dataframe
# Out:
#      Name  Age         Place
# 0   Sanvi    6       Chirala
# 1   Seivi    6       Chirala
# 2  Ramana   85  Narasaraopet
# 3  Manasa   30  Narasaraopet
# 4   Ramya   30     Hyderabad
# 5  Himani    6     Hyderabad
# 6   Tinku   28     Hyderabad

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1['Name'])
# Out:
# pandas.core.series.Series

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  23:02    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  23:11    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
pd.read_excel('sample-xls-file-for-testing.xls')
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df=pd.read_excel('sample-xls-file-for-testing.xls')

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.keys()
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
# df.keys() and df.columns gives the same output

# %%
df.sheet_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_45832/3397573432.py in <module>
# ----> 1 df.sheet_names
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sheet_names'

# %%
# if excelsheet have more than one sheet the above
# tab works

# %%
for i in df.sheet_names:
    pd.read_excel('sample-xls-file-for-testing.xls',sheet_name=i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_45832/1420657766.py in <module>
# ----> 1 for i in df.sheet_names:
#       2     pd.read_excel('sample-xls-file-for-testing.xls',sheet_name=i)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sheet_names'

# %%
pd.read_csv('https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# how to bring dataset from html page

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# the above data is in list format

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[0]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 07-12-2023  23:30    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
import pandas as pd

# %%
l=pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)

# %%
d="""{"name": "rajarajeswari",
"mailid":"raji@gmail.com",
"marks":[10,20,30,40,50],
"syllabus":["kidsneuron","techneuron","ineuron","robotics"]}"""

# %%
type(d)
# Out:
# str

# %%
# given data is in dict format but it is givving str as output
# because it is written in between double quotes

# %%
import json
import pandas as pd

# %%
result=json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result["name"]
# Out:
# 'rajarajeswari'

# %%
# while using online json viewer we have to remove quotes

# %%
pd.DataFrame(result['syllabus'])
# Out:
#             0
# 0  kidsneuron
# 1  techneuron
# 2     ineuron
# 3    robotics

# %%
result['syllabus']
# Out:
# ['kidsneuron', 'techneuron', 'ineuron', 'robotics']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1=d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56379',
#   'id': 2031271223,
#   'node_id': 'I_kwDOAA0YD855Er03',
#   'number': 56379,
#   'title': "BUG: strings 'nan' istead of NaN values if pandas DataFrame is enlarged by setting values using DataFrame.at[] or DataFrame.loc[] with non-existent indexers",
#   'user': {'login': 'EBenkler',
#    'id': 16223042,
#    'node_id': 'MDQ6VXNlcjE2MjIzMDQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16223042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EBenkler',
# ...

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 16223042
# 1126981
# 47963215
# 8078968
# 8078968
# 10647082
# 10647082
# 33153091
# 1126981
# 332746
# 124158982
# 66105100
# 37619875
# 33491632
# 30049606
# 72032381
# 64710719
# 17667690
# 132615348
# 30159171
# 10647082
# 91160475
# 4811862
# 144291871
# 1020496
# 45640029
# 149019786
# 6614121
# 609873
# 63046380

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56379/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56379',
#   'id': 2031271223,
#   'node_id': 'I_kwDOAA0YD855Er03',
#   'number': 56379,
#   'title': "BUG: strings 'nan' istead of NaN values if pandas DataFrame is enlarged by setting values using DataFrame.at[] or DataFrame.loc[] with non-existent indexers",
#   'user': {'login': 'EBenkler',
#    'id': 16223042,
#    'node_id': 'MDQ6VXNlcjE2MjIzMDQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16223042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EBenkler',
# ...

# %%
df2=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is BA08-EA00
#
#  Directory of C:\Users\91903
#
# 08-12-2023  00:02    <DIR>          .
# 02-04-2023  19:05    <DIR>          ..
# 31-07-2022  11:32    <DIR>          .astropy
# 31-07-2022  11:13    <DIR>          .conda
# 30-11-2022  14:28    <DIR>          .cufflinks
# 08-05-2023  16:03    <DIR>          .idea
# 07-12-2023  21:38    <DIR>          .ipynb_checkpoints
# 21-02-2022  17:38    <DIR>          .ipython
# 05-03-2022  10:37    <DIR>          .jupyter
# 31-07-2022  11:40    <DIR>          .matplotlib
# 03-12-2023  18:07    <DIR>          __pycache__
# 08-10-2022  22:23            21,198 15th jan exception handling part1.ipynb
# 26-02-2023  16:06             6,880 16th jan logging.ipynb
# 25-08-2022  18:29            56,638 18th dec practice.ipynb
# 18-08-2023  10:20            63,220 19th dec practice.ipynb
# 11-09-2023  17:09         4,672,436 2023 20dec for loop  and while ipynb.ipynb
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...
